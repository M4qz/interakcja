# %% [markdown]
# ## Statistics 101

# %% [markdown]
# ### BIRAFFE2 dataset
#
# In today's class, we will recall the basics of statistics.
# To make it more fun and related to the our affective research, we will start by loading the BIRAFFE2 dataset collected using, among others, BITalino (i.e., the older brother of the PLUX's family of devices we use in class).
#
# We will use the **BIRAFFE2-procedure** subset with a logs of stimuli presentation and user responses and **BIRAFFE2-metadata.csv** file.
#
# For more details, see the [full record at Zenodo](https://doi.org/10.5281/zenodo.3865859).

# %%
# necessary imports
import io
import glob
import numpy as np
import pandas as pd

# for stats
from scipy import stats
import statistics
import statsmodels.api as sm
import statsmodels.formula.api as smf

# import matplotlib library
import matplotlib.pyplot as plt
# if you work locally (not at Google Colab) you can activate interactive plots by changing "inline" to "notebook"
# %matplotlib inline

# import bokeh
import bokeh.io, bokeh.plotting
bokeh.io.output_notebook()

# %%
# Download the dataset (to Virtual Machine local filesystem)
# !wget https://zenodo.org/record/3865860/files/BIRAFFE2-metadata.csv?download=1
# !wget https://zenodo.org/record/3865860/files/BIRAFFE2-procedure.zip?download=1

# !mv "BIRAFFE2-metadata.csv?download=1" "BIRAFFE2-metadata.csv"
# !mv "BIRAFFE2-procedure.zip?download=1" "BIRAFFE2-procedure.zip"
# Out:
# --2024-03-23 10:34:20--  https://zenodo.org/record/3865860/files/BIRAFFE2-metadata.csv?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.98.238, 188.185.79.172, 188.184.103.159, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.238|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/3865860/files/BIRAFFE2-metadata.csv [following]
# --2024-03-23 10:34:20--  https://zenodo.org/records/3865860/files/BIRAFFE2-metadata.csv
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 27324 (27K) [text/plain]
# Saving to: ‘BIRAFFE2-metadata.csv?download=1’
#
# BIRAFFE2-metadata.c 100%[===================>]  26.68K  --.-KB/s    in 0.1s
#
# 2024-03-23 10:34:21 (245 KB/s) - ‘BIRAFFE2-metadata.csv?download=1’ saved [27324/27324]
#
# --2024-03-23 10:34:21--  https://zenodo.org/record/3865860/files/BIRAFFE2-procedure.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.184.98.238, 188.185.79.172, 188.184.103.159, ...
# Connecting to zenodo.org (zenodo.org)|188.184.98.238|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/3865860/files/BIRAFFE2-procedure.zip [following]
# --2024-03-23 10:34:21--  https://zenodo.org/records/3865860/files/BIRAFFE2-procedure.zip
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 35900571 (34M) [application/octet-stream]
# Saving to: ‘BIRAFFE2-procedure.zip?download=1’
#
# BIRAFFE2-procedure. 100%[===================>]  34.24M  14.4MB/s    in 2.4s
#
# 2024-03-23 10:34:24 (14.4 MB/s) - ‘BIRAFFE2-procedure.zip?download=1’ saved [35900571/35900571]

# %%
# unpack the zip file
# !unzip "BIRAFFE2-procedure.zip"
# Out:
# Archive:  BIRAFFE2-procedure.zip
#    creating: BIRAFFE2-procedure/
#   inflating: BIRAFFE2-procedure/SUB997-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB977-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB969-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB959-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB948-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB938-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB920-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB915-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB911-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB900-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB869-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB854-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB829-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB821-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB817-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB812-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB797-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB790-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB778-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB758-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB721-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB700-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB688-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB683-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB676-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB672-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB668-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB667-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB665-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB653-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB644-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB621-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB614-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB608-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB603-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB589-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB577-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB576-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB575-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB572-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB570-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB568-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB560-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB556-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB555-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB553-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB504-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB503-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB502-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB465-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB457-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB456-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB444-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB431-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB410-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB407-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB405-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB404-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB403-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB391-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB388-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB383-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB375-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB370-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB356-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB348-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB340-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB336-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB333-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB330-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB322-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB320-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB318-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB314-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB275-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB267-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB256-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB249-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB246-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB236-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB230-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB228-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB223-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB222-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB211-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB208-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB202-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB200-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB195-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB193-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB181-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB175-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB170-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB161-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB157-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB153-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB148-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB141-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB136-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB120-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB119-Procedure.csv
#   inflating: BIRAFFE2-procedure/SUB103-Procedure.csv
#   inflating: LICENSE
#   inflating: README

# %%
# generates a list of all procedure files
procedure_files = glob.glob("BIRAFFE2-procedure/*.csv")
# and counts them
len(procedure_files)
# Out:
# 102

# %% [markdown]
# OK, so we have 102 files (one for each subject). What's inside?

# %%
# let's load the first file
procedure_file = pd.read_csv(procedure_files[0], sep=';', na_values='None')
# rename the columns to be more pythonic (and to not generate problems later ;) )
procedure_file.columns = ['TIMESTAMP', 'ID', 'COND', 'IADS_ID', 'IAPS_ID', 'ANS_VALENCE', 'ANS_AROUSAL', 'ANS_TIME', 'EVENT']
# let's see the file
procedure_file
# Out:
#         TIMESTAMP     ID COND  IADS_ID  IAPS_ID  ANS_VALENCE  ANS_AROUSAL  \
# 0    1.580985e+09    NaN  NaN      NaN      NaN          NaN          NaN
# 1    1.580985e+09    NaN  NaN      NaN      NaN          NaN          NaN
# 2    1.580985e+09    NaN  NaN      NaN      NaN          NaN          NaN
# 3    1.580985e+09    NaN  NaN      NaN      NaN          NaN          NaN
# 4    1.580985e+09    NaN  NaN      NaN      NaN          NaN          NaN
# ..            ...    ...  ...      ...      ...          ...          ...
# 191  1.580988e+09  391.0   P+      NaN   8178.0        9.000        5.653
# 192  1.580988e+09  391.0  PS+    355.0   8158.0        9.000        6.005
# 193  1.580988e+09  391.0   S-    275.0      NaN        1.662        5.469
# 194  1.580988e+09  391.0   S+    817.0      NaN        7.939        5.689
# 195  1.580988e+09    NaN  NaN      NaN      NaN          NaN          NaN
#
#      ANS_TIME                                              EVENT
# 0         NaN                                     BASELINE START
# 1         NaN                                       BASELINE END
# 2         NaN                                       INSTRUCTIONS
# 3         NaN                                     TUTORIAL START
# 4         NaN  BITalino error: The computer lost communicatio...
# ..        ...                                                ...
# 191     3.450                                                NaN
# 192     5.750                                                NaN
# 193     6.000                                                NaN
# 194     2.167                                                NaN
# 195       NaN                                 STIMULI PART 2 END
#
# [196 rows x 9 columns]

# %% [markdown]
# Meaning of the columns (accrodingly to [the docs](https://doi.org/10.5281/zenodo.3865860)):
# * `TIMESTAMP` – *not important for us*,
# * `ID` – subject ID,
# * `COND` – one of nine conditions (`P+`, `P0`, `P-`, `S+`, `S0`, `S-`, `PS+`, `PS0`, `PS-`) – information about presented stimuli (picture `P` and/or sound `S`) and its affective sign (`+` = positive, `0` = neutral, `-` = negative),
# * `IADS_ID;IAPS_ID` – *not important for us*,
# * `ANS_VALENCE;ANS_AROUSAL` – values in `[1; 9]` ranges indicating the point selected by the subject in the Valence-arousal space
#   * Valence ranges from negative (`1`) via neutral (`5`) to positive (`9`),
#   * while Arousal ranges from low arousal (`1`) via neutral (`5`) to high arousal (`9`),
# * `ANS_TIME` – response time (`0` is a moment when widget appeared
# on the screen); `NaN` indicates that the subject has not made any
# choice but left the default option,
# * `EVENT` – *not important for us*.

# %% [markdown]
# Experimental procedure (for more elaborate version, see [the docs](https://doi.org/10.5281/zenodo.3865860)):
# 1. Affective image and/or picture is presented to the subject (for 6 seconds). Stimuli may be positive/negative/neutral (i.e., it should evoke emotions with high/low/middle valence). Information is saved as `COND`.
# 2. Stimuli disappears. The answer widget is presented (2D space with valence and arousal axes as described above) with default answer (valence = 5; arousal = 5).
# 3. There is 6 seconds to move the coursor to other place in the 2D space.
# 4. After 6 seconds the widget disappears. The marked answer is saved in the log (as `ANS_VALENCE;ANS_AROUSAL`). Response time (till the last coursor movement) is saved as `ANS_TIME`.
# 5. There is a break (for 6 seconds) and next stimuli is presented.
#
# Other notes:
# * At the beginning there are some test stimuli - these should **not** be analysed (they are marked as `test` in `COND` column).

# %% [markdown]
# Before we start, let's contatenate all the procedure files together (so the processing will be easier) and load the metadata file.

# %%
procedure_files_list = []

for proc_filename in procedure_files:
    # read the file
    procedure_file = pd.read_csv(proc_filename, sep=';', na_values='None')

    # change the column names as above
    procedure_file.columns = ['TIMESTAMP', 'ID', 'COND', 'IADS_ID',
                              'IAPS_ID', 'ANS_VALENCE', 'ANS_AROUSAL',
                              'ANS_TIME', 'EVENT']

    # add the dataframe to the list
    procedure_files_list.append(procedure_file)

# concatenation of all files
procedure = pd.concat(procedure_files_list, ignore_index=True)
# Out:
# <ipython-input-7-fddd3704cde8>:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   procedure_file = pd.read_csv(proc_filename, sep=';', na_values='None')
# <ipython-input-7-fddd3704cde8>:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   procedure_file = pd.read_csv(proc_filename, sep=';', na_values='None')
# <ipython-input-7-fddd3704cde8>:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   procedure_file = pd.read_csv(proc_filename, sep=';', na_values='None')
# <ipython-input-7-fddd3704cde8>:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   procedure_file = pd.read_csv(proc_filename, sep=';', na_values='None')
# <ipython-input-7-fddd3704cde8>:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   procedure_file = pd.read_csv(proc_filename, sep=';', na_values='None')

# %%
# ok, we have loaded more than 13 000 000 records into one DataFrame
procedure = procedure[procedure['COND'] != 'test']
procedure
# Out:
#              TIMESTAMP     ID COND  IADS_ID  IAPS_ID  ANS_VALENCE  \
# 0         1.580985e+09    NaN  NaN      NaN      NaN          NaN
# 1         1.580985e+09    NaN  NaN      NaN      NaN          NaN
# 2         1.580985e+09    NaN  NaN      NaN      NaN          NaN
# 3         1.580985e+09    NaN  NaN      NaN      NaN          NaN
# 4         1.580985e+09    NaN  NaN      NaN      NaN          NaN
# ...                ...    ...  ...      ...      ...          ...
# 13038759  1.580296e+09  246.0   P-      NaN   6200.0        2.390
# 13038760  1.580296e+09  246.0   S-    422.0      NaN        2.571
# 13038761  1.580296e+09  246.0  PS0    245.0   9404.0        4.294
# 13038762  1.580296e+09  246.0  PS+    415.0   5910.0        4.353
# 13038763  1.580296e+09    NaN  NaN      NaN      NaN          NaN
#
#           ANS_AROUSAL  ANS_TIME  \
# 0                 NaN       NaN
# 1                 NaN       NaN
# 2                 NaN       NaN
# 3                 NaN       NaN
# 4                 NaN       NaN
# ...               ...       ...
# 13038759        5.879     5.867
# 13038760        7.108     2.000
# 13038761        5.823     1.900
# 13038762        3.117     5.333
# 13038763          NaN       NaN
#
#                                                       EVENT
# 0                                            BASELINE START
# 1                                              BASELINE END
# 2                                              INSTRUCTIONS
# 3                                            TUTORIAL START
# 4         BITalino error: The computer lost communicatio...
# ...                                                     ...
# 13038759                                                NaN
# 13038760                                                NaN
# 13038761                                                NaN
# 13038762                                                NaN
# 13038763                                 STIMULI PART 2 END
#
# [13038764 rows x 9 columns]

# %%
procedure.isna().sum()
# Out:
# TIMESTAMP             0
# ID             13026556
# COND           13026556
# IADS_ID        13030592
# IAPS_ID        13030595
# ANS_VALENCE    13026556
# ANS_AROUSAL    13026556
# ANS_TIME       13026918
# EVENT             12208
# dtype: int64

# %%
# we also have to load the metadata file
# we only save the ID, AGE, SEX and Big Five personality traits
metadata = pd.read_csv('BIRAFFE2-metadata.csv', sep=';', na_values='None')[['ID', 'AGE', 'SEX', 'OPENNESS', 'CONSCIENTIOUSNESS', 'NEUROTICISM', 'AGREEABLENESS', 'EXTRAVERSION']]

# %%
# Here you can see the Big Five personality traits in [1,10] range; they can be interpreted as low (1-3), medium (4-6) and high (7-10) values
metadata
# Out:
#       ID  AGE SEX  OPENNESS  CONSCIENTIOUSNESS  NEUROTICISM  AGREEABLENESS  \
# 0    103   18   M         6                  6            2              3
# 1    119   22   F         6                  7            6              2
# 2    120   21   F         1                  2            2              2
# 3    136   22   F         7                  3            8              5
# 4    141   21   M         3                  1            7              5
# ..   ...  ...  ..       ...                ...          ...            ...
# 98   948   23   F         7                 10            1              3
# 99   959   21   M         8                  7            2              8
# 100  969   21   M         3                  8            6              1
# 101  977   20   F         6                  7            2              7
# 102  997   21   M         1                  3            7              4
#
#      EXTRAVERSION
# 0               4
# 1               2
# 2               2
# 3              10
# 4               4
# ..            ...
# 98              7
# 99              4
# 100             5
# 101             8
# 102             1
#
# [103 rows x 8 columns]

# %%
records = procedure[procedure["COND"].notnull()]
records.isna().sum()
# Out:
# TIMESTAMP          0
# ID                 0
# COND               0
# IADS_ID         4036
# IAPS_ID         4039
# ANS_VALENCE        0
# ANS_AROUSAL        0
# ANS_TIME         362
# EVENT          12208
# dtype: int64

# %% [markdown]
# ### Descriptive statistics
#
# The dataset is loaded into two [DataFrames](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html): `metadata` and `procedure`.
#
# Let's start with some basic stats!
#
# **Task 1**. Calculate the following values (you can use methods from [`pandas`](https://pandas.pydata.org/docs/index.html), [`statistics`](https://docs.python.org/3/library/statistics.html), [`scipy.stats`](https://docs.scipy.org/doc/scipy/reference/stats.html) or any other libraries):
# * minimum and maximum of subject's `age`
# * mean and median of subject's `age`
# * standard deviation of subject's `age`
#
# *(check also [`pd.DataFrame.describe()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html))*

# %%
# _FILL_IN_YOUR_CODE_HERE
print("Age mean: %.2f, max: %.d, std: %.4f" % (metadata["AGE"].mean(), max(metadata["AGE"]), metadata["AGE"].std()))
# Out:
# Age mean: 21.63, max: 26, std: 1.3209

# %%
metadata.describe()
# Out:
#                ID         AGE    OPENNESS  CONSCIENTIOUSNESS  NEUROTICISM  \
# count  103.000000  103.000000  103.000000         103.000000   103.000000
# mean   493.553398   21.631068    5.485437           5.679612     5.378641
# std    253.749712    1.320950    2.226683           2.620483     2.461932
# min    103.000000   18.000000    1.000000           1.000000     1.000000
# 25%    261.500000   21.000000    4.000000           4.000000     3.000000
# 50%    457.000000   21.000000    6.000000           6.000000     5.000000
# 75%    674.000000   22.000000    7.000000           8.000000     7.000000
# max    997.000000   26.000000   10.000000          10.000000    10.000000
#
#        AGREEABLENESS  EXTRAVERSION
# count     103.000000    103.000000
# mean        6.252427      5.844660
# std         2.403912      2.304119
# min         1.000000      1.000000
# 25%         5.000000      4.000000
# 50%         7.000000      6.000000
# 75%         8.000000      8.000000
# max        10.000000     10.000000

# %%
metadata.isna().sum()
# Out:
# ID                   0
# AGE                  0
# SEX                  0
# OPENNESS             0
# CONSCIENTIOUSNESS    0
# NEUROTICISM          0
# AGREEABLENESS        0
# EXTRAVERSION         0
# dtype: int64

# %% [markdown]
# ### Some plots
#
# A standard way to get familiar with the data is to plot it! Our data consists of valence and arousal scores which forms 2D space. Let's plot the data to see whether there is something interesting.
#
# **Task 2**: prepare the plots:
# 1. of all valence and arousal scores,
# 2. of valence and arousal answers per each of nine conditions.
#
# Note 1: ignore the rows with `NaN` values in `COND`, `ANS-VALENCE`, `ANS-AROUSAL` columns.
# Note 2: to select rows related to specific condition(s) you can use:
# `new_dataframe = procedure[(procedure['COND'] == 'P+') | (procedure['COND'] == 'S+')]`
# Note 3: to select only one column, you can use:
# `column = procedure['COND']`

# %%
# _FILL_IN_YOUR_CODE_HERE
# https://en.wikipedia.org/wiki/Emotion_classification#/media/File:Circumplex_model_of_emotion.svg
relevant_samples = procedure[procedure['ANS_AROUSAL'].notna() & procedure['ANS_VALENCE'].notna()]
arousal = relevant_samples["ANS_AROUSAL"]
valence = relevant_samples["ANS_VALENCE"]
plt.scatter(valence, arousal, s=0.3, alpha=0.7)
plt.title("Arousal-Valence scatter plot")
plt.xlabel("Arousal (1-10)")
plt.ylabel("Valence (1-10)")
plt.show()

# %%
conditions = procedure.loc[procedure["COND"].notnull(), "COND"].unique()
records = procedure[procedure["COND"].notnull()]

def plot_condition(df, condition, cond_col="COND", arousal_col="ANS_AROUSAL", valence_col="ANS_VALENCE"):
  data = df[df[cond_col] == condition]
  arousal = data[arousal_col]
  valence = data[valence_col]
  plt.scatter(arousal, valence, s=0.3, alpha=0.7)
  plt.title(f"Arousal-Valence ({condition}) scatter plot")
  plt.xlabel("Arousal (1-10)")
  plt.ylabel("Valence (1-10)")
  plt.show()

for cond in conditions:
  plot_condition(records, cond)

# %% [markdown]
# ### Student's t-test and Wilcoxon signed-rank test
#
# As you probably noticed (on the plots), it seems that the **valence** scores are much lower for `-` condition (`P-`, `S-`, `PS-`) than for neutral one (`P0`, `S0`, `PS0`), and much higher for `+` condition (`P+`, `S+`, `PS+`) than for neutral one.
#
# We will examine this in a moment, but first we need to clarify the key concepts...
#
# **Task 3**: Taking the above situation as an example (verifying if the valence is lower in the `-` condition than in the neutral group), describe (in a few words) what are **Null hypothesis** and **Alternative hypothesis**

# %% [markdown]
# `_FILL_IN_YOUR_ANSWERS_HERE`

# %%
#H_0 =  "+" and "-" valence scores have the same distribution
#H_1 = "-" and "+" valence scores have different distribution

# %% [markdown]
# **Task 4:** Verify whether the differences mentioned do indeed exist. To do so, perform two t-tests (`-` vs `0` and `+` vs `0`).
#
# Note: use the test for related samples (as the results for both conditions are from the same subjects group) not the independent ones! (e.g., [`scipy.stats.ttest_rel()`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_rel.html))

# %%
# _FILL_IN_YOUR_CODE_HERE
neutral_samples = records[records["COND"].str.contains("0")]
negative_samples = records[records["COND"].str.contains("-")]
positive_samples = records[records["COND"].str.contains("\+")]
print(negative_samples.shape, neutral_samples.shape, positive_samples.shape)
# Out:
# (3928, 9) (3938, 9) (3934, 9)

# %%
# sample size is simillar (assumption 1)
plt.hist(neutral_samples["ANS_VALENCE"], alpha=0.5)
plt.hist(negative_samples["ANS_VALENCE"], alpha=0.5)
plt.hist(positive_samples["ANS_VALENCE"], alpha=0.5)
# Out:
# (array([  68.,   39.,   58.,  103.,  226.,  645.,  547.,  638.,  582.,
#         1028.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
negative_samples.iloc[0]
# Out:
# TIMESTAMP      1580985088.384432
# ID                         391.0
# COND                         PS-
# IADS_ID                    278.0
# IAPS_ID                   3051.0
# ANS_VALENCE                  1.0
# ANS_AROUSAL                  5.0
# ANS_TIME                   3.467
# EVENT                        NaN
# Name: 68, dtype: object

# %%
# the distribuion is not normal!
print(negative_samples["ANS_VALENCE"].std()**2, neutral_samples["ANS_VALENCE"].std()**2, positive_samples["ANS_VALENCE"].std()**2)
# variances are more or less the same
# Out:
# 2.634760411170291 4.467316512662099 3.1996808711321343

# %% [markdown]
# **Task 5**: But... Did you remember to check the assumptions of the t-test? You can use the Shapiro-Wilks Test to check the normality of the sample ([`scipy.stats.shapiro()`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.shapiro.html)).

# %% [markdown]
# ![paranormal.jpg](data:image/jpeg;base64,...)
#
# *([source](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2465539/))*

# %% [markdown]
# *Note: We test the normality of the distribution here to emphasise that it is important to **check the assumptions** of each test we perform.*
#
# *In real life situations, checking the normality of the distribution before the t-test is not really necessary. Check [the slides](https://www.researchgate.net/publication/299497976_Silly_or_Pointless_Things_People_Do_When_Analyzing_Data_1_Testing_for_Normality_as_a_Precursor_to_a_t-test) for more details.*

# %%
# _FILL_IN_YOUR_CODE_HERE
res_negative = stats.shapiro(negative_samples["ANS_VALENCE"])
res_negative.pvalue
# Out:
# 0.0

# %%
res_neutral = stats.shapiro(neutral_samples["ANS_VALENCE"])
res_neutral.pvalue
# Out:
# 2.5653838249068697e-30

# %%
res_positive = stats.shapiro(positive_samples["ANS_VALENCE"])
res_positive.pvalue
# Out:
# 6.438890773455461e-39

# %% [markdown]
# Oh... The p-value is smaller than 0.05, so the data was **not** drawn from a normal distribution, and we cannot use the t-test...
#
# But we can use the **non-parametric** test instead: the Wilcoxon signed-rank test ([`scipy.stats.wilcoxon()`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.wilcoxon.html)).
# *(Do you know what the **non-parametric** means?)*
#
# Note: when the samples are **independent**, the proper non-parametric test is the Mann-Whitney U rank test ([`scipy.stats.mannwhitneyu`](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.mannwhitneyu.html)).
#
# **Task 6**: perform the Wilcoxon test to evaluate the differences in valence scores - now the results will be realible, so you can finally state whether there are differences or not!

# %%
# _FILL_IN_YOUR_CODE_HERE
# AND STATE WHETHER THERE ARE SIGNIFICANT DIFFERENCES OR NOT :)
# https://en.wikipedia.org/wiki/Nonparametric_statistics
ids = neutral_samples["ID"].sample(20)
ids = set(negative_samples["ID"]).intersection(set(ids))
neutral_sample = neutral_samples.loc[neutral_samples["ID"].isin(ids), "ANS_VALENCE"]
negative_sample = negative_samples.loc[negative_samples["ID"].isin(ids), "ANS_VALENCE"]
positive_sample = positive_samples.loc[positive_samples["ID"].isin(ids), "ANS_VALENCE"]
wilcoxon_neg = stats.wilcoxon(neutral_sample, negative_sample)
wilcoxon_pos = stats.wilcoxon(neutral_sample, positive_sample)
print(wilcoxon_neg)
print(wilcoxon_pos)
# Out:
# WilcoxonResult(statistic=22907.5, pvalue=4.919119005373279e-80)
# WilcoxonResult(statistic=25050.0, pvalue=6.872006017533422e-78)

# %% [markdown]
# ### ANOVA
#
# Hooray! There are significant differences between `+`/`-` and `0` conditions!
#
# But analyses of our data are not limited to such simple differences. In our dataset we also has the personality profile (represented as five variables in `metadata`). How do they impact our dependent variables (`ANS-VALENCE` and `ANS-AROUSAL`)?

# %% [markdown]
# First, we need to combine these variables into our `procedure` dataset:

# %%
# to speed-up the process, you can remove the rows without the ANS values...
procedure = procedure[procedure['ANS_VALENCE'].notnull()]
# ... and training-related rows
procedure = procedure[procedure['COND'] != 'train']

# %%
procedure = pd.merge(procedure, metadata, how="left", on="ID")

# %%
procedure.to_csv("data.csv")

# %%
import seaborn as sns
sns.heatmap(procedure.iloc[:, -5:].corr())
# Out:
# <Axes: >

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
procedure.iloc[:, -5:].corr().to_numpy()
# Out:
# array([[ 1.        ,  0.06095101,  0.08400572,  0.05975704,  0.21616757],
#        [ 0.06095101,  1.        , -0.26766173,  0.11352496,  0.18798709],
#        [ 0.08400572, -0.26766173,  1.        , -0.00307583, -0.39595494],
#        [ 0.05975704,  0.11352496, -0.00307583,  1.        ,  0.33846905],
#        [ 0.21616757,  0.18798709, -0.39595494,  0.33846905,  1.        ]])

# %% [markdown]
# **Task 7**: Perform the ANOVA (more precisely 5-way ANOVA as we have five independent variables) to check how `ANS_VALENCE` (and `ANS_AROUSAL`) is influenced by the personality profile.
#
# Note 1: Remember that we have repeated / dependent measures (i.e., one subject was in all groups), so we have to include random effects for each subject. We can use [linear mixed effects models](https://www.statsmodels.org/stable/mixed_linear.html) and their implementation in `statsmodels` (as `scipy` does not support it).
#
# Note 2: As a result of this step you should get a table with some p-values related to independent variables
#
# Note 3: The formula takes the form: `DEP ~ IND_1 + IND_2 + IND_1*IND_2`, where `DEP` is dependent variable, `IND_X` is independent variable, `+` means another factor and `*` indicates interaction between factors.
#
# Note 4: You need two models (one for valence and one for arousal) or you need to perform MANOVA (M stands for multiple dependent variables)
#
# Note 5: The p-value is in the `P>|z|` column.

# %%
# _FILL_IN_YOUR_CODE_HERE
from statsmodels.regression.mixed_linear_model import MixedLM
from statsmodels.formula.api import mixedlm
import itertools
independent = ["OPENNESS","CONSCIENTIOUSNESS","NEUROTICISM","AGREEABLENESS" ,"EXTRAVERSION"]
perms = itertools.permutations(independent, 2)
# perms = [str(p1 + "*" + p2) for p1, p2 in perms]
# perms = "+".join(perms)
model_formula = "+".join(independent) #+ "+" + perms

arousal_formula = "ANS_AROUSAL ~ " + model_formula
valence_formula = "ANS_VALENCE ~ " + model_formula

arousal_model = mixedlm(arousal_formula, procedure, groups=procedure["COND"])
arousal = arousal_model.fit()

valence_model = mixedlm(valence_formula, procedure, groups=procedure["COND"])
valence = valence_model.fit()

print(valence.summary())
print(arousal.summary())
# Out:
#           Mixed Linear Model Regression Results
# ==========================================================
# Model:             MixedLM Dependent Variable: ANS_VALENCE
# No. Observations:  11800   Method:             REML
# No. Groups:        9       Scale:              3.3386
# Min. group size:   1308    Log-Likelihood:     -23905.2125
# Max. group size:   1314    Converged:          Yes
# Mean group size:   1311.1
# ----------------------------------------------------------
#                   Coef. Std.Err.   z   P>|z| [0.025 0.975]
# ----------------------------------------------------------
# Intercept         4.265    0.627 6.800 0.000  3.036  5.494
# OPENNESS          0.020    0.008 2.537 0.011  0.005  0.035
# CONSCIENTIOUSNESS 0.001    0.007 0.079 0.937 -0.013  0.014
# NEUROTICISM       0.002    0.008 0.279 0.781 -0.013  0.018
# AGREEABLENESS     0.031    0.008 4.137 0.000  0.016  0.046
# EXTRAVERSION      0.010    0.009 1.128 0.259 -0.007  0.027
# Group Var         3.469    0.949
# ==========================================================
#
#            Mixed Linear Model Regression Results
# ============================================================
# Model:             MixedLM  Dependent Variable:  ANS_AROUSAL
# No. Observations:  11800    Method:              REML
# No. Groups:        9        Scale:               3.8071
# Min. group size:   1308     Log-Likelihood:      -24670.8321
# Max. group size:   1314     Converged:           Yes
# Mean group size:   1311.1
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          5.229    0.239 21.875 0.000  4.760  5.697
# OPENNESS           0.042    0.008  5.031 0.000  0.026  0.059
# CONSCIENTIOUSNESS  0.032    0.007  4.373 0.000  0.017  0.046
# NEUROTICISM        0.019    0.008  2.230 0.026  0.002  0.035
# AGREEABLENESS     -0.025    0.008 -3.101 0.002 -0.041 -0.009
# EXTRAVERSION      -0.007    0.009 -0.712 0.477 -0.025  0.012
# Group Var          0.432    0.112
# ============================================================

# %% [markdown]
# A significant result in ANOVA only tells us that the null hypothesis of equality of all levels of a given variable / given interaction of variables has been rejected. So there is some difference, but we don't know between which levels. To examine this we need to do additional post-hoc tests.
#
# **Task 8:** Do the post-hoc tests for significant results in ANOVA(s).
#
# Tip: You can use [`pairwise_tukeyhsd()`](https://www.statsmodels.org/stable/generated/statsmodels.stats.multicomp.pairwise_tukeyhsd.html) from `statmodels`.

# %%
# _FILL_IN_YOUR_CODE_HERE
from statsmodels.stats.multicomp import pairwise_tukeyhsd

significant_arousal = ["OPENNESS", "AGREEABLENESS"]
for sig in significant_arousal:
  res = pairwise_tukeyhsd(procedure["ANS_VALENCE"], procedure[sig], alpha=0.05)
  print(f"------ ANS_VALENCE, {sig} ------")
  print(res)
# Out:
# ------ ANS_VALENCE, OPENNESS ------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      1      3   0.1827 0.6812 -0.1319  0.4972  False
#      1      4   0.2936 0.2716 -0.0824  0.6695  False
#      1      5      0.4 0.0023  0.0879  0.7121   True
#      1      6   0.2587 0.2195  -0.059  0.5764  False
#      1      7   0.2941 0.0667 -0.0097   0.598  False
#      1      8  -0.0306    1.0 -0.3836  0.3224  False
#      1      9    0.429 0.0077  0.0658  0.7922   True
#      1     10   0.7433 0.0686 -0.0271  1.5138  False
#      3      4   0.1109 0.9814 -0.2183  0.4401  False
#      3      5   0.2174 0.1637 -0.0365  0.4712  False
#      3      6    0.076 0.9928 -0.1847  0.3367  False
#      3      7   0.1115 0.8908 -0.1322  0.3551  False
#      3      8  -0.2133 0.4148 -0.5159  0.0894  False
#      3      9   0.2464 0.2676 -0.0682  0.5609  False
#      3     10   0.5607 0.3281 -0.1881  1.3094  False
#      4      5   0.1065  0.985 -0.2204  0.4333  False
#      4      6  -0.0349    1.0 -0.3671  0.2974  False
#      4      7   0.0006    1.0 -0.3184  0.3196  False
#      4      8  -0.3242 0.1317 -0.6902  0.0419  False
#      4      9   0.1355 0.9717 -0.2405  0.5114  False
#      4     10   0.4498 0.6844 -0.3268  1.2263  False
#      5      6  -0.1413 0.7462 -0.3991  0.1164  False
#      5      7  -0.1059 0.9106 -0.3464  0.1346  False
#      5      8  -0.4306 0.0003 -0.7307 -0.1305   True
#      5      9    0.029    1.0 -0.2831  0.3411  False
#      5     10   0.3433 0.8887 -0.4044   1.091  False
#      6      7   0.0354    1.0 -0.2123  0.2832  False
#      6      8  -0.2893 0.0811 -0.5953  0.0167  False
#      6      9   0.1703 0.7691 -0.1474  0.4881  False
#      6     10   0.4846 0.5402 -0.2654  1.2347  False
#      7      8  -0.3247 0.0161 -0.6163 -0.0332   True
#      7      9   0.1349 0.9066  -0.169  0.4388  False
#      7     10   0.4492 0.6331 -0.2951  1.1935  False
#      8      9   0.4596 0.0018  0.1067  0.8126   True
#      8     10   0.7739 0.0452  0.0083  1.5396   True
#      9     10   0.3143 0.9412 -0.4561  1.0848  False
# ----------------------------------------------------
# ------ ANS_VALENCE, AGREEABLENESS ------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj   lower  upper  reject
# ---------------------------------------------------
#      1      2   0.0101    1.0 -0.4866 0.5067  False
#      1      3   0.6385  0.001  0.1606 1.1164   True
#      1      4   0.3805 0.1711 -0.0644 0.8254  False
#      1      5   0.5126 0.0052  0.0884 0.9367   True
#      1      6   0.4729 0.0193  0.0406 0.9051   True
#      1      7   0.4385 0.0244  0.0294 0.8476   True
#      1      8   0.3765 0.1067 -0.0349  0.788  False
#      1      9   0.3249  0.382   -0.12 0.7698  False
#      1     10   0.7669    0.0   0.322 1.2118   True
#      2      3   0.6284 0.0004  0.1801 1.0768   True
#      2      4   0.3704 0.1238 -0.0425 0.7834  False
#      2      5   0.5025 0.0019  0.1119  0.893   True
#      2      6   0.4628 0.0093  0.0635 0.8621   True
#      2      7   0.4284 0.0109  0.0543 0.8025   True
#      2      8   0.3665 0.0644 -0.0102 0.7431  False
#      2      9   0.3148 0.3183 -0.0982 0.7278  False
#      2     10   0.7568    0.0  0.3439 1.1698   True
#      3      4   -0.258 0.5329 -0.6482 0.1322  False
#      3      5  -0.1259  0.986 -0.4924 0.2405  False
#      3      6  -0.1656 0.9292 -0.5414 0.2101  False
#      3      7     -0.2 0.7262 -0.5489 0.1488  False
#      3      8   -0.262 0.3517 -0.6135 0.0896  False
#      3      9  -0.3136 0.2455 -0.7038 0.0766  False
#      3     10   0.1284 0.9897 -0.2618 0.5186  False
#      4      5   0.1321 0.9545 -0.1901 0.4543  False
#      4      6   0.0924 0.9971 -0.2404 0.4252  False
#      4      7    0.058 0.9999  -0.244   0.36  False
#      4      8  -0.0039    1.0 -0.3091 0.3013  False
#      4      9  -0.0556    1.0 -0.4046 0.2934  False
#      4     10   0.3864 0.0167  0.0374 0.7354   True
#      5      6  -0.0397    1.0 -0.3442 0.2648  False
#      5      7  -0.0741 0.9974 -0.3447 0.1965  False
#      5      8   -0.136 0.8627 -0.4101 0.1381  False
#      5      9  -0.1877 0.7073 -0.5099 0.1345  False
#      5     10   0.2543 0.2695 -0.0679 0.5765  False
#      6      7  -0.0344    1.0 -0.3175 0.2487  False
#      6      8  -0.0963  0.988 -0.3828 0.1902  False
#      6      9   -0.148 0.9254 -0.4808 0.1848  False
#      6     10    0.294 0.1378 -0.0388 0.6268  False
#      7      8  -0.0619 0.9988 -0.3121 0.1882  False
#      7      9  -0.1136  0.974 -0.4156 0.1884  False
#      7     10   0.3284 0.0207  0.0264 0.6304   True
#      8      9  -0.0517 0.9999 -0.3569 0.2535  False
#      8     10   0.3903 0.0021  0.0851 0.6955   True
#      9     10    0.442 0.0025   0.093  0.791   True
# ---------------------------------------------------

# %%
significant_valence = ["OPENNESS","CONSCIENTIOUSNESS","NEUROTICISM","AGREEABLENESS" ]
for sig in significant_valence:
  res = pairwise_tukeyhsd(procedure["ANS_AROUSAL"], procedure[sig], alpha=0.05)
  print(f"------ ANS_AROUSAL, {sig} ------")
  print(res)
# Out:
# ------ ANS_AROUSAL, OPENNESS ------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      1      3  -0.2372 0.0881 -0.4908  0.0163  False
#      1      4   0.3198 0.0294  0.0168  0.6229   True
#      1      5  -0.0454 0.9998  -0.297  0.2062  False
#      1      6  -0.0177    1.0 -0.2739  0.2384  False
#      1      7   0.1042 0.9257 -0.1407  0.3492  False
#      1      8   0.5308    0.0  0.2463  0.8153   True
#      1      9   0.0354    1.0 -0.2574  0.3282  False
#      1     10  -0.1609 0.9968  -0.782  0.4602  False
#      3      4    0.557    0.0  0.2917  0.8224   True
#      3      5   0.1919 0.0866 -0.0128  0.3965  False
#      3      6   0.2195 0.0328  0.0093  0.4297   True
#      3      7   0.3415    0.0  0.1451  0.5379   True
#      3      8    0.768    0.0   0.524   1.012   True
#      3      9   0.2726 0.0241  0.0191  0.5262   True
#      3     10   0.0763    1.0 -0.5273  0.6799  False
#      4      5  -0.3652 0.0006 -0.6287 -0.1017   True
#      4      6  -0.3375  0.003 -0.6053 -0.0697   True
#      4      7  -0.2156 0.1861 -0.4727  0.0416  False
#      4      8    0.211 0.3938 -0.0841  0.5061  False
#      4      9  -0.2844  0.086 -0.5875  0.0186  False
#      4     10  -0.4807 0.2936 -1.1067  0.1453  False
#      5      6   0.0277    1.0 -0.1801  0.2355  False
#      5      7   0.1496 0.2871 -0.0443  0.3435  False
#      5      8   0.5762    0.0  0.3342  0.8181   True
#      5      9   0.0808 0.9864 -0.1708  0.3324  False
#      5     10  -0.1155 0.9996 -0.7183  0.4872  False
#      6      7   0.1219 0.6178 -0.0778  0.3217  False
#      6      8   0.5485    0.0  0.3018  0.7952   True
#      6      9   0.0531 0.9994  -0.203  0.3092  False
#      6     10  -0.1432 0.9983 -0.7479  0.4615  False
#      7      8   0.4266    0.0  0.1915  0.6616   True
#      7      9  -0.0688 0.9944 -0.3138  0.1761  False
#      7     10  -0.2651 0.9089 -0.8652  0.3349  False
#      8      9  -0.4954    0.0 -0.7799 -0.2109   True
#      8     10  -0.6917  0.015 -1.3089 -0.0745   True
#      9     10  -0.1963 0.9877 -0.8174  0.4248  False
# ----------------------------------------------------
# ------ ANS_AROUSAL, CONSCIENTIOUSNESS ------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      1      2   0.0986 0.9919 -0.2112  0.4084  False
#      1      3  -0.3344 0.0103 -0.6253 -0.0436   True
#      1      4   0.0661 0.9991  -0.212  0.3443  False
#      1      5   0.1049 0.9735 -0.1732  0.3831  False
#      1      6  -0.0472 0.9999 -0.3215   0.227  False
#      1      7   0.2177   0.18 -0.0389  0.4744  False
#      1      8   0.2317 0.1803 -0.0415  0.5049  False
#      1      9   0.0814 0.9987 -0.2419  0.4046  False
#      1     10    0.021    1.0 -0.2776  0.3196  False
#      2      3  -0.4331 0.0002 -0.7347 -0.1314   True
#      2      4  -0.0325    1.0 -0.3219  0.2569  False
#      2      5   0.0063    1.0 -0.2831  0.2957  False
#      2      6  -0.1459 0.8408 -0.4316  0.1398  False
#      2      7   0.1191 0.9271 -0.1497  0.3879  False
#      2      8   0.1331 0.9007 -0.1516  0.4178  False
#      2      9  -0.0173    1.0 -0.3503  0.3158  False
#      2     10  -0.0777 0.9987 -0.3868  0.2315  False
#      3      4   0.4006 0.0001  0.1315  0.6696   True
#      3      5   0.4393    0.0  0.1703  0.7084   True
#      3      6   0.2872 0.0215  0.0222  0.5522   True
#      3      7   0.5522    0.0  0.3054  0.7989   True
#      3      8   0.5661    0.0  0.3022  0.8301   True
#      3      9   0.4158 0.0013  0.1003  0.7313   True
#      3     10   0.3554 0.0042  0.0653  0.6456   True
#      4      5   0.0388    1.0 -0.2165   0.294  False
#      4      6  -0.1134 0.9183 -0.3644  0.1376  False
#      4      7   0.1516 0.5484   -0.08  0.3832  False
#      4      8   0.1656 0.5297 -0.0843  0.4155  False
#      4      9   0.0152    1.0 -0.2886   0.319  False
#      4     10  -0.0452    1.0 -0.3225  0.2322  False
#      5      6  -0.1522 0.6566 -0.4032  0.0988  False
#      5      7   0.1128 0.8756 -0.1188  0.3444  False
#      5      8   0.1268 0.8457 -0.1231  0.3767  False
#      5      9  -0.0235    1.0 -0.3274  0.2803  False
#      5     10  -0.0839 0.9944 -0.3613  0.1935  False
#      6      7    0.265 0.0084   0.038  0.4919   True
#      6      8    0.279 0.0121  0.0334  0.5245   True
#      6      9   0.1286 0.9404 -0.1716  0.4289  False
#      6     10   0.0682 0.9987 -0.2052  0.3417  False
#      7      8    0.014    1.0 -0.2117  0.2397  False
#      7      9  -0.1364 0.8854 -0.4206  0.1479  False
#      7     10  -0.1967 0.3058 -0.4526  0.0591  False
#      8      9  -0.1504 0.8536 -0.4497  0.1489  False
#      8     10  -0.2107 0.2976 -0.4832  0.0617  False
#      9     10  -0.0604 0.9999  -0.383  0.2622  False
# ----------------------------------------------------
# ------ ANS_AROUSAL, NEUROTICISM ------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      1      2   0.1946 0.9369 -0.2556  0.6449  False
#      1      3   0.3643 0.2558 -0.0925  0.8211  False
#      1      4  -0.0521    1.0 -0.5197  0.4154  False
#      1      5   0.2957 0.5386 -0.1532  0.7446  False
#      1      6   0.1199 0.9984 -0.3473  0.5871  False
#      1      7   0.4804 0.0237  0.0333  0.9275   True
#      1      8   0.3882 0.1852 -0.0716   0.848  False
#      1      9  -0.3315 0.7642 -0.9296  0.2666  False
#      1     10   0.2239 0.8931 -0.2489  0.6968  False
#      2      3   0.1696 0.3775  -0.062  0.4013  False
#      2      4  -0.2468 0.0611  -0.499  0.0054  False
#      2      5   0.1011 0.8993 -0.1146  0.3168  False
#      2      6  -0.0748 0.9951 -0.3263  0.1767  False
#      2      7   0.2858 0.0008  0.0739  0.4976   True
#      2      8   0.1936 0.2273 -0.0439   0.431  False
#      2      9  -0.5262 0.0083 -0.9764 -0.0759   True
#      2     10   0.0293    1.0 -0.2325  0.2911  False
#      3      4  -0.4164    0.0 -0.6802 -0.1527   True
#      3      5  -0.0686 0.9949 -0.2977  0.1605  False
#      3      6  -0.2444 0.0949 -0.5075  0.0187  False
#      3      7   0.1161 0.8338 -0.1094  0.3416  False
#      3      8   0.0239    1.0 -0.2257  0.2736  False
#      3      9  -0.6958 0.0001 -1.1526  -0.239   True
#      3     10  -0.1403 0.8353 -0.4133  0.1326  False
#      4      5   0.3479 0.0005   0.098  0.5977   True
#      4      6    0.172 0.6452 -0.1093  0.4534  False
#      4      7   0.5326    0.0   0.286  0.7791   True
#      4      8   0.4403    0.0  0.1715  0.7092   True
#      4      9  -0.2794 0.6755 -0.7469  0.1882  False
#      4     10   0.2761 0.0792 -0.0145  0.5667  False
#      5      6  -0.1758 0.4337  -0.425  0.0733  False
#      5      7   0.1847 0.1379 -0.0244  0.3938  False
#      5      8   0.0925 0.9649 -0.1424  0.3274  False
#      5      9  -0.6272 0.0004 -1.0761 -0.1783   True
#      5     10  -0.0718 0.9972 -0.3314  0.1878  False
#      6      7   0.3606 0.0002  0.1147  0.6064   True
#      6      8   0.2683 0.0498  0.0001  0.5365   True
#      6      9  -0.4514 0.0685 -0.9186  0.0158  False
#      6     10   0.1041 0.9811  -0.186  0.3941  False
#      7      8  -0.0922  0.962 -0.3237  0.1392  False
#      7      9  -0.8119    0.0  -1.259 -0.3648   True
#      7     10  -0.2565 0.0499 -0.5129 -0.0001   True
#      8      9  -0.7197    0.0 -1.1795   -0.26   True
#      8     10  -0.1643 0.6894 -0.4422  0.1136  False
#      9     10   0.5554 0.0077  0.0826  1.0283   True
# ----------------------------------------------------
# ------ ANS_AROUSAL, AGREEABLENESS ------
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ====================================================
# group1 group2 meandiff p-adj   lower   upper  reject
# ----------------------------------------------------
#      1      2  -0.0214    1.0 -0.4232  0.3805  False
#      1      3   -0.375 0.0662 -0.7617  0.0116  False
#      1      4   -0.031    1.0  -0.391  0.3289  False
#      1      5   -0.185 0.7923 -0.5282  0.1581  False
#      1      6  -0.0202    1.0 -0.3699  0.3296  False
#      1      7  -0.2503   0.33 -0.5813  0.0807  False
#      1      8  -0.0241    1.0  -0.357  0.3087  False
#      1      9  -0.3243 0.1199 -0.6842  0.0357  False
#      1     10  -0.3459 0.0718 -0.7058  0.0141  False
#      2      3  -0.3537 0.0631 -0.7164   0.009  False
#      2      4  -0.0097    1.0 -0.3438  0.3244  False
#      2      5  -0.1637 0.8289 -0.4797  0.1523  False
#      2      6   0.0012    1.0 -0.3219  0.3242  False
#      2      7  -0.2289 0.3296 -0.5316  0.0737  False
#      2      8  -0.0028    1.0 -0.3075   0.302  False
#      2      9  -0.3029 0.1144  -0.637  0.0312  False
#      2     10  -0.3245 0.0654 -0.6586  0.0096  False
#      3      4    0.344 0.0202  0.0283  0.6597   True
#      3      5     0.19 0.5791 -0.1065  0.4864  False
#      3      6   0.3548 0.0084  0.0509  0.6588   True
#      3      7   0.1247 0.9281 -0.1575  0.4069  False
#      3      8   0.3509 0.0038  0.0665  0.6353   True
#      3      9   0.0507    1.0  -0.265  0.3664  False
#      3     10   0.0292    1.0 -0.2865  0.3449  False
#      4      5   -0.154 0.6898 -0.4147  0.1067  False
#      4      6   0.0109    1.0 -0.2584  0.2801  False
#      4      7  -0.2193 0.1235 -0.4636  0.0251  False
#      4      8   0.0069    1.0   -0.24  0.2538  False
#      4      9  -0.2933 0.0343 -0.5756 -0.0109   True
#      4     10  -0.3148 0.0153 -0.5972 -0.0325   True
#      5      6   0.1649 0.5149 -0.0815  0.4112  False
#      5      7  -0.0652  0.995 -0.2842  0.1537  False
#      5      8   0.1609 0.3916 -0.0609  0.3827  False
#      5      9  -0.1392 0.8013 -0.3999  0.1214  False
#      5     10  -0.1608 0.6329 -0.4215  0.0998  False
#      6      7  -0.2301 0.0478 -0.4592 -0.0011   True
#      6      8   -0.004    1.0 -0.2357  0.2278  False
#      6      9  -0.3041  0.013 -0.5733 -0.0349   True
#      6     10  -0.3257 0.0051 -0.5949 -0.0565   True
#      7      8   0.2262 0.0149  0.0238  0.4285   True
#      7      9   -0.074 0.9944 -0.3184  0.1704  False
#      7     10  -0.0956 0.9664 -0.3399  0.1488  False
#      8      9  -0.3002 0.0047 -0.5471 -0.0532   True
#      8     10  -0.3217 0.0015 -0.5686 -0.0748   True
#      9     10  -0.0216    1.0 -0.3039  0.2608  False
# ----------------------------------------------------

# %% [markdown]
# ### This place is for you!
#
# If class isn't over and you still have some time, now is a good time to do some analysis of your own. Do you have any ideas on what you can investigate?
